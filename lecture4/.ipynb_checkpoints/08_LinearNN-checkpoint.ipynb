# %% [markdown]
# # Linear neural networks

# %% [markdown]
# ### Linear Regression Basics
# - Linear and Softmax regression can be casted to linear neural networks
# - Assumption: The relationship between the independent variables **x** and the dependent variable **y** is linear
# - The linearity assumpetion says, that the **label** (price) ca be expressed as a **weighted** sum of the **features** (size, year of renovation)
#
#  $$\mathcal{price} = (w_{size} * size) + (w_{year} * year) + b$$
#
# - The weights determine the influence of the feature on the prediction
# - The **bias** says, what value the predicted price should have, when all of the features take value 0
# - - Even if Size = 0 never happens, we need the bias or else we will imit the expressivity of our model
#
# - **Goal =** choose weights and the bias such that on average, the predictions made best fit the true prices (labels) on our data.
# ![Drag Racing](whiteboard\linear_regression.png)

# %% [markdown]
# ### Linear Regression in ML
# - Since in ML we work with high dimensional datasets
# - When input consists of ${d}$ features, we express the prediction $\hat{y}$
#
# $$\hat{y} = w_{1}x_{1} + ... + w_{d}x_{d} + b$$
#
# - collecting into **vectors**
# - - features $\mathbf{x} \in \mathbb{R}^{d}$
# - - weights $\mathbf{w} \in \mathbb{R}^{d}$
#
# $$\hat{y} = \mathbf{w}^T \mathbf{x} + b$$
#
# - This Vector corresponds to features of a single data example
# - - It is better to refer to features of entire dataset of $n$
# - For a collection of features we use matrix $\matbf{X}
#
# $$\hat{y} = \mathbf{X}\mathbf{w} + b$$
#
# **Goal =** Given features of a training set $\mathbf{X}$ known labels $\mathbf{y}$. Find the weight vector $\mathbf{w}$ and the bias term $b$. The new examples will be predicted with the lowest error.
#
# ![Drag Racing](whiteboard\scalar-vector-matrix.svg)

# %% [markdown]
# ### Loss Function - Least Squared Error
# - A measure of *fitness* - qualitfy measure of our model
# - Quantifies the *real* and the *predicted* value of the target
# - Usually a non-negative number, where **smaller = better** and **perfect = 0**
# - - $i$ = example
# - - $y^i$ = true label
# - - $\hat{y}^i$ = prediction
# ![Drag Racing](whiteboard\least_squared.png)

# %% [markdown]
# ### Making Predictions with the learned Model
# - Given the learned linear model $\mathbf{\hat{w}}^{T}\mathbf{x} + \hat{b}$, we can now predict price of new houses
# - Give its size $x_{1}$ and year $x_{2}$

# %% [markdown]
# ### Normal Distribution (Normalverteilung) and Squared Loss
# - values are normaly distributed around the mean
# - mean = durchschnitt
# - std = standardabweichung
# ![normal_distr](whiteboard\normal_distribution.svg)

# %% [markdown]
# ### From Linear Regression to Deep Networks
# - Neural Networks cover a much richer family of models
# - Now we rewrite things in a *layer* notation
#
# - Inputs = $x_{1}, ..., x_{d}$, so the number of inputs (*feature dimensionality*) is $d$
# - Output = $o_{1}$, so the number of Outputs is 1
#
# ![normal_distr](whiteboard\singleneuron.svg)
#
# - Linear regression models as neural networks consists of just a single neuron or as *single-layer neural networks*
# - Since in linear regression, every input is connected to every output = it is a *fully-connected layer* or **dense layer**

# %% [markdown]
# ## Problem description
#
# Predict the price of flat in Wurzbrug based on its size (in sqm) and time since last renovation (in yrs).
#
# * input: $\mathbf{x} \in \mathbb{R}^2$, each example $\mathbf{x}$ consists of 2 features
# * output: $y \in \mathbb{R}$, single output (price)
# * Thus the dataset matrix = $\mathbf{X} \in \mathbb{R}^{x \times 2}$

# %%
# import torch
# --- YOUR CODE HERE ---
import random
import torch

# %% [markdown]
# ### Generate synthetic data
#
# Generate some data which are a bit similar to reality:
#
# * sizes from normal distribution with mean 70 and std 20
# * years from normal distribution with mean 5 and std 2
# * clamp the input data into reasonable values (e.g. sizes btw $[20, 150]$, years btw $[0, 10]$)

# %%
# Fix number of data examples (e.g. to 1000)
# --- YOUR CODE HERE ---
num_examples = 1000

# generate random input data
# --- YOUR CODE HERE ---
sizes = torch.normal(mean=70, std=20, size=(num_examples, 1))
years = torch.normal(mean=5, std=2, size=(num_examples, 1))

sizes = torch.clamp(sizes, min=20, max=150)
years = torch.clamp(years, min=0, max=10)

# make sure the inputs are a single tensor with 2 colums
# --- YOUR CODE HERE ---
features = torch.cat((sizes, years),1)
features.shape
# Out:
# torch.Size([1000, 2])

# %% [markdown]
# ### Generate synthetic labels
#
# We are working with liner model so assume labels are generated as $y = \mathbf{x}^T \mathbf{w} + b + e$, where $e$ is random gaussian noise.
#
# Fix true parameters to the following values:
#
# * weight for size = 10.
# * weight for years = -20.
# * bias = 100
# * random noise is Gaussian with mean 0. and standard deviation 5.

# %%
# fix true parameters for the linear regression
# --- YOUR CODE HERE ---
true_w = torch.tensor([10.0, -20.0])

# bias
# --- YOUR CODE HERE ---
true_b = 100.0

# generate outputs from linear regression model y = x^T w + b + e
# --- YOUR CODE HERE ---
labels = torch.matmul(features, true_w) + true_b
labels += torch.normal(mean=0, std=5, size=labels.shape) #noise e
labels = labels.reshape((-1, 1))
labels.shape
# Out:
# torch.Size([1000, 1])

# %% [markdown]
# ### Plot data
#
# Use matplotlib library to plot a scatter graph of price against the size of the apartment

# %%
# use matplilib to plot a scatter of price against the size
# --- YOUR CODE HERE ---
from matplotlib import pyplot as plt
# %matplotlib inline
plt.scatter(sizes.detach().numpy(), labels.detach().numpy()) # detach tensor graphs and convert to ndarray

# %% [markdown]
# ### Data loading
#
# Write a generator to load batches of data. It shall recieve as arguments the data inputs, outputs and the batch size and yield a batch of examples at every call, where batch is a tuple of inputs and outputs in the batch. Remember to shuffle the data at the initiation of the generator so that you do not get always the same batches.
#
# - iterator: Iterates over a list
# - generator: Generates a list
#
# - *param*: inputs, outputs, batch_size
# - *yield*: batch (inputs, outputs)
#
#
# - range:
# - - start: Starting number of the sequence.
# - - stop: Generate numbers up to, but not including this number.
# - - step: Difference between each number in the sequence.
#
#
# - min:
# - - return the lowest number of an iterable

# %%
# define a function (generator) iter_data(inputs, outputs, batch_size) -> (batch_inputs, batch_outputs)
# --- YOUR CODE HERE ---
import random

def generator(features, labels, batch_size):
    num_examples = len(features) # just assign lenght of our input to a variable
    indices = list(range(num_examples)) # create a list of indices with respect to the number of examples (0,1,...,999)
    random.shuffle(indices)
    for i in range(0, num_examples, batch_size): # with batch_size 10 -> i=0, i=10, i=20, ... i=990
        # define range of batch
        # with batch_size 10 & num_examples 1000 
            # (0 + 10, 1000) = 10, (10 + 10, 1000) = 20, ..., (1000 + 10, 1000) = 1000 
        end = min(i + batch_size, num_examples)

        # create a tensor out of the list with indices from the examples
        batch_indices = torch.tensor(indices[i:end]) 
        yield features[batch_indices], labels[batch_indices]

# %% [markdown]
# ### Iterate through data
#
# Check your generator works by iterating once through all the data and printing out the batch at every iteration.

# %%
# write a for loop to load batches from data and print out the batches
# --- YOUR CODE HERE ---
batch_size = 10

for X, y in generator(features, labels, batch_size):
    print(X, '\n', y)
# Out:
# tensor([[ 94.6569,   4.0064],
#         [ 75.3330,   4.2735],
#         [ 96.5219,   5.2125],
#         [103.6778,   7.2997],
#         [ 32.2565,   2.4552],
#         [ 89.5812,   8.6479],
#         [ 85.0165,   1.1649],
#         [ 75.2892,   6.3794],
#         [ 52.8059,   2.2530],
#         [ 60.1368,   6.6167]])
#  tensor([[963.8585],
#         [774.6801],
#         [954.5699],
#         [989.5178],
#         [382.0598],
#         [823.2692],
#         [931.2133],
#         [723.9789],
#         [585.3342],
#         [570.5997]])
# tensor([[80.7631,  6.4424],
#         [43.0506,  1.4844],
#         [59.4047,  3.5378],
#         [49.7034,  1.4481],
#         [69.0880,  6.0962],
#         [52.7138,  3.6358],
#         [62.4809,  5.5245],
#         [46.6772,  4.1899],
#         [64.2590,  5.5094],
#         [69.6016,  3.1782]])
#  tensor([[781.1950],
#         [511.5587],
#         [626.6823],
#         [566.2442],
#         [670.4229],
#         [548.7434],
#         [612.1385],
#         [472.8435],
#         [631.6115],
#         [743.9159]])
# tensor([[ 76.1999,   3.5961],
#         [ 78.6511,   1.3766],
#         [ 69.0650,   6.7862],
#         [ 58.4556,   7.3771],
#         [ 77.9931,   0.0000],
#         [104.6276,   2.8804],
#         [ 78.6703,   7.1709],
#         [ 58.4614,   3.7157],
#         [116.6481,   5.1402],
#         [ 54.8388,   6.0729]])
#  tensor([[ 791.1308],
#         [ 862.0297],
#         [ 648.3755],
#         [ 539.3239],
#         [ 883.8293],
#         [1087.1342],
#         [ 739.2540],
#         [ 610.4418],
#         [1161.2581],
#         [ 528.5248]])
# tensor([[70.7626,  3.2825],
#         [28.7525,  1.2666],
#         [76.4681,  3.4299],
#         [69.1707,  6.0015],
#         [52.3414,  3.4679],
#         [81.5658,  5.0026],
#         [92.2640,  5.7585],
#         [63.7236,  3.2289],
#         [71.1786,  6.3303],
#         [29.1788,  4.9197]])
#  tensor([[734.5552],
#         [359.5591],
#         [791.5818],
#         [671.9677],
#         [554.9912],
#         [806.6014],
#         [907.5192],
#         [671.5786],
#         [687.3332],
#         [291.8108]])
# tensor([[ 47.4247,   4.6000],
#         [ 96.4771,   7.2743],
#         [107.5469,   7.7868],
#         [ 43.7760,   6.2840],
#         [ 87.5692,   4.4849],
#         [ 61.2645,   5.2591],
#         [ 53.9348,   4.6132],
#         [ 57.8144,   3.5780],
#         [ 61.6970,   5.2745],
#         [ 37.4390,   3.7881]])
#  tensor([[ 481.9301],
#         [ 921.4323],
#         [1023.5784],
#         [ 416.3516],
#         [ 890.3297],
#         [ 607.0099],
#         [ 541.7850],
#         [ 614.9032],
#         [ 612.5609],
#         [ 403.4400]])
# tensor([[ 64.6995,   6.8576],
#         [ 75.4417,   3.0999],
#         [ 89.0849,   6.1229],
#         [ 97.0216,   2.6489],
#         [ 79.5056,   5.1863],
#         [107.2352,   7.5598],
#         [ 73.2091,   7.1982],
#         [101.6651,   3.4530],
#         [ 39.5012,   1.8000],
#         [ 86.8251,   0.0000]])
#  tensor([[ 611.3572],
#         [ 795.3908],
#         [ 870.3336],
#         [1013.5969],
#         [ 785.8166],
#         [1020.2944],
#         [ 685.4771],
#         [1051.9729],
#         [ 457.7105],
#         [ 972.3770]])
# tensor([[114.0798,   5.2789],
#         [ 97.6341,   5.0096],
#         [ 86.1377,   3.1933],
#         [ 72.6003,   5.4322],
#         [ 20.0000,   6.6883],
#         [ 59.7054,   0.2597],
#         [ 74.3503,   3.1001],
#         [ 54.1506,   5.2877],
#         [ 36.4626,   3.4552],
#         [ 48.0391,   0.4175]])
#  tensor([[1134.0459],
#         [ 982.3889],
#         [ 898.8901],
#         [ 713.7108],
#         [ 164.9457],
#         [ 687.7353],
#         [ 782.1356],
#         [ 539.5254],
#         [ 387.6320],
#         [ 567.1638]])
# tensor([[ 65.9362,   4.2135],
#         [ 71.5290,   2.6954],
#         [ 71.9739,   5.6272],
#         [ 83.3446,   4.3239],
#         [ 85.0482,   4.1312],
#         [ 77.7951,   4.2507],
#         [122.1510,   6.0907],
#         [ 59.3100,  10.0000],
#         [ 97.2090,   5.2927],
#         [ 53.2347,   6.0303]])
#  tensor([[ 675.0506],
#         [ 765.9176],
#         [ 705.3663],
#         [ 849.8488],
#         [ 870.2152],
#         [ 790.0323],
#         [1204.5942],
#         [ 493.3572],
#         [ 968.5084],
#         [ 508.7521]])
# tensor([[ 86.2717,   1.9963],
#         [ 63.4341,   6.3336],
#         [ 34.0223,   4.4482],
#         [ 60.4827,   2.4891],
#         [ 76.6231,   1.9169],
#         [ 76.1089,   7.8547],
#         [ 89.2280,   1.1941],
#         [111.3172,   3.8817],
#         [ 90.7149,   6.7336],
#         [ 82.7068,   4.2052]])
#  tensor([[ 927.9233],
#         [ 603.0331],
#         [ 362.6597],
#         [ 652.8865],
#         [ 831.1996],
#         [ 711.9912],
#         [ 968.7323],
#         [1137.0233],
#         [ 867.8614],
#         [ 841.1238]])
# tensor([[67.9964,  7.0994],
#         [61.7106,  2.4386],
#         [82.4182,  6.2838],
#         [82.7180,  7.4989],
#         [84.9721,  2.1775],
#         [88.7675,  4.4588],
#         [87.6109,  2.5107],
#         [36.4437,  4.7226],
#         [75.9048,  5.4263],
#         [85.0402,  5.7643]])
#  tensor([[632.7601],
#         [669.8679],
#         [800.8040],
#         [779.7192],
#         [907.7396],
#         [895.9820],
#         [924.3389],
#         [372.4220],
#         [751.5370],
#         [840.1659]])
# tensor([[37.4545,  5.1732],
#         [80.7584,  0.9622],
#         [82.4046,  4.1393],
#         [86.1656,  6.4351],
#         [92.3882,  4.5261],
#         [76.6622,  4.6766],
#         [73.8460,  2.5709],
#         [80.4951,  7.0703],
#         [48.6649,  7.1314],
#         [71.0249,  9.4780]])
#  tensor([[370.0944],
#         [889.3784],
#         [830.8849],
#         [831.9868],
#         [941.1984],
#         [777.7676],
#         [789.6299],
#         [761.4800],
#         [444.1504],
#         [624.2495]])
# tensor([[33.1208,  5.0775],
#         [76.8390,  4.8367],
#         [64.0160,  3.4690],
#         [54.1038,  7.7732],
#         [20.0000,  6.8334],
#         [55.7782,  6.5520],
#         [56.0363,  6.8016],
#         [75.1251,  2.8233],
#         [56.8500,  5.4869],
#         [48.1520,  4.2045]])
#  tensor([[340.6901],
#         [772.2844],
#         [665.4880],
#         [481.0242],
#         [164.1717],
#         [540.1371],
#         [523.2032],
#         [789.4903],
#         [565.6500],
#         [492.5389]])
# tensor([[ 82.3632,   6.2980],
#         [107.3056,   3.2835],
#         [ 63.2302,   5.2504],
#         [ 70.6929,   6.8623],
#         [ 73.9464,   3.3205],
#         [ 72.9218,   6.3131],
#         [ 74.6484,   7.6464],
#         [102.1505,   6.3528],
#         [ 79.7490,   0.8670],
#         [ 82.7671,   5.8838]])
#  tensor([[ 788.6680],
#         [1105.8821],
#         [ 627.4042],
#         [ 671.0714],
#         [ 768.3893],
#         [ 694.1125],
#         [ 695.3464],
#         [ 996.5354],
#         [ 876.8292],
#         [ 813.6554]])
# tensor([[ 61.3454,   3.1626],
#         [ 58.7597,   4.6233],
#         [ 67.9336,   4.6098],
#         [ 24.9861,   4.7457],
#         [104.4369,   1.5272],
#         [ 84.1580,   2.8893],
#         [ 57.5163,   7.3023],
#         [ 41.8689,   2.7568],
#         [ 20.0000,   5.8486],
#         [ 25.4056,   4.3053]])
#  tensor([[ 654.7458],
#         [ 589.0312],
#         [ 682.7625],
#         [ 259.9552],
#         [1112.4514],
#         [ 876.7656],
#         [ 526.3442],
#         [ 462.4960],
#         [ 182.0046],
#         [ 271.5691]])
# tensor([[64.1433,  5.8978],
#         [33.7011,  2.2676],
#         [78.5241,  6.6263],
#         [74.1398,  1.9912],
#         [91.7005,  5.8748],
#         [56.0972,  7.2853],
#         [92.6339,  5.6237],
#         [82.6522,  4.5146],
#         [84.7687,  3.2022],
#         [93.7230,  5.5622]])
#  tensor([[624.9445],
#         [395.4842],
#         [753.2880],
#         [792.7720],
#         [898.7006],
#         [512.4244],
#         [915.1260],
#         [844.0835],
#         [892.7858],
#         [923.8065]])
# tensor([[67.5443,  7.2235],
#         [64.8577,  3.9076],
#         [71.7586,  8.1120],
#         [95.9935,  6.1556],
#         [59.2865,  2.9735],
#         [99.5733,  4.1933],
#         [93.4670,  2.7699],
#         [85.7356,  5.5144],
#         [85.0871,  7.2739],
#         [88.4343,  2.0962]])
#  tensor([[ 628.4591],
#         [ 671.3463],
#         [ 658.4222],
#         [ 936.8544],
#         [ 636.2178],
#         [1008.8056],
#         [ 986.3431],
#         [ 842.4402],
#         [ 806.6561],
#         [ 939.2678]])
# tensor([[81.9121,  5.3979],
#         [82.4092,  9.7224],
#         [73.1237,  6.0536],
#         [56.2775,  3.5676],
#         [80.8830,  4.6394],
#         [32.7818,  4.6257],
#         [66.8160,  6.3999],
#         [59.5281,  5.7230],
#         [95.8470,  4.6797],
#         [68.3117,  6.2215]])
#  tensor([[820.4150],
#         [731.9755],
#         [713.2634],
#         [595.7379],
#         [810.0441],
#         [333.9790],
#         [638.6617],
#         [577.0164],
#         [966.4532],
#         [659.4901]])
# tensor([[102.9499,   6.0940],
#         [ 44.6097,   1.3322],
#         [ 76.4891,   2.5598],
#         [ 30.6500,   3.9868],
#         [ 49.4005,   5.8594],
#         [ 81.0223,   6.1209],
#         [115.1917,   3.5890],
#         [ 83.4948,   4.7883],
#         [ 81.2950,   3.7620],
#         [ 90.1290,   1.7125]])
#  tensor([[1004.8441],
#         [ 516.4032],
#         [ 812.2979],
#         [ 328.2808],
#         [ 474.2757],
#         [ 797.0071],
#         [1173.9868],
#         [ 841.5499],
#         [ 837.5978],
#         [ 973.9013]])
# tensor([[66.3944,  4.2523],
#         [20.0000,  4.2756],
#         [72.6112,  2.8574],
#         [64.4475,  2.6334],
#         [80.8857,  0.7702],
#         [79.6413,  5.0283],
#         [70.4747,  3.6288],
#         [41.1557,  6.0448],
#         [57.9788,  4.8007],
#         [66.9921,  4.7730]])
#  tensor([[684.7589],
#         [216.7904],
#         [768.8300],
#         [682.9494],
#         [894.0234],
#         [801.4835],
#         [725.5685],
#         [384.1062],
#         [580.3006],
#         [673.5419]])
# tensor([[ 46.5629,   4.0523],
#         [ 59.5841,   0.7614],
#         [ 65.0031,   1.6749],
#         [ 79.9116,   8.5596],
#         [ 80.5456,   6.3850],
#         [ 56.6330,   4.4737],
#         [ 99.2026,   7.9303],
#         [ 62.4211,   6.0550],
#         [ 46.4202,   5.9790],
#         [105.7801,   7.7380]])
#  tensor([[ 491.2766],
#         [ 671.6295],
#         [ 711.2272],
#         [ 732.0156],
#         [ 773.6523],
#         [ 582.8511],
#         [ 932.7744],
#         [ 603.4474],
#         [ 448.0643],
#         [1004.4083]])
# tensor([[88.6884,  6.8558],
#         [86.8443,  5.6620],
#         [68.7100,  4.3971],
#         [80.2503,  3.1709],
#         [80.7499,  5.8842],
#         [56.1063,  2.8159],
#         [67.6031,  3.8359],
#         [83.1759,  5.3504],
#         [71.2939,  6.3253],
#         [73.5363,  8.7119]])
#  tensor([[856.6642],
#         [846.3022],
#         [706.9881],
#         [840.4375],
#         [792.9710],
#         [604.8207],
#         [696.8240],
#         [824.6396],
#         [694.1964],
#         [663.3409]])
# tensor([[75.0284,  0.9167],
#         [70.5220,  0.8487],
#         [90.8317,  6.0226],
#         [76.3435,  5.1375],
#         [85.6924,  7.1674],
#         [90.6228,  9.3111],
#         [58.9740,  2.7858],
#         [82.2469,  4.7125],
#         [53.5070,  5.3853],
#         [96.8446,  3.8288]])
#  tensor([[825.3855],
#         [780.8851],
#         [889.2565],
#         [758.2542],
#         [817.2342],
#         [816.5635],
#         [628.2844],
#         [829.1431],
#         [530.1826],
#         [994.0109]])
# tensor([[109.6136,   6.6045],
#         [ 40.1166,   5.6827],
#         [ 70.4591,   6.1320],
#         [ 25.8423,   8.3177],
#         [ 72.5658,   2.5510],
#         [ 82.9037,   7.6702],
#         [ 70.4623,   3.7399],
#         [ 93.5410,   6.2284],
#         [ 39.7062,   7.9869],
#         [ 73.4195,   4.4418]])
#  tensor([[1071.5358],
#         [ 391.6656],
#         [ 686.1473],
#         [ 192.9560],
#         [ 775.8907],
#         [ 769.6460],
#         [ 724.2930],
#         [ 909.3878],
#         [ 339.0286],
#         [ 742.4681]])
# tensor([[ 71.8390,   6.7620],
#         [ 84.0019,   5.0872],
#         [ 20.0000,   4.2133],
#         [ 94.7583,   3.5986],
#         [ 89.5270,   2.1927],
#         [113.6038,   5.6157],
#         [ 66.9274,   4.6424],
#         [ 69.8405,   6.9320],
#         [ 78.6700,   2.2590],
#         [ 52.6347,   6.3308]])
#  tensor([[ 684.3243],
#         [ 843.1584],
#         [ 209.8431],
#         [ 980.1309],
#         [ 950.5102],
#         [1115.1451],
#         [ 679.8810],
#         [ 670.0042],
#         [ 841.3912],
#         [ 505.7263]])
# tensor([[71.3772,  5.9734],
#         [61.7024,  4.0782],
#         [91.6290,  6.2455],
#         [45.2852,  3.7111],
#         [54.0815,  4.8531],
#         [29.1291,  6.4145],
#         [60.7994,  6.7657],
#         [20.2574,  6.6064],
#         [80.5417,  7.8314],
#         [61.9871,  4.5902]])
#  tensor([[694.9464],
#         [644.1089],
#         [889.1373],
#         [477.3283],
#         [547.1287],
#         [260.9179],
#         [567.6665],
#         [164.0690],
#         [747.5358],
#         [633.9789]])
# tensor([[ 80.0042,   8.0008],
#         [ 48.4357,   6.0835],
#         [ 85.5364,   5.6301],
#         [ 56.7201,   6.2451],
#         [ 54.7630,   5.4094],
#         [ 86.8497,   4.7783],
#         [ 48.2796,   7.6752],
#         [ 53.7253,   8.1149],
#         [ 62.9337,   5.2947],
#         [105.5176,   6.0015]])
#  tensor([[ 742.4158],
#         [ 459.9836],
#         [ 840.5029],
#         [ 542.9855],
#         [ 530.5014],
#         [ 879.3919],
#         [ 432.8877],
#         [ 469.9449],
#         [ 612.6258],
#         [1030.8419]])
# tensor([[76.1539,  3.4277],
#         [74.0513,  0.9531],
#         [68.0387,  8.8030],
#         [83.6408, 10.0000],
#         [61.7846,  5.2934],
#         [77.7328,  2.4938],
#         [67.3459,  5.5833],
#         [68.8874,  7.8866],
#         [57.4410,  3.8783],
#         [62.6304,  9.4156]])
#  tensor([[789.0200],
#         [819.0121],
#         [607.1954],
#         [741.0384],
#         [609.0464],
#         [823.8882],
#         [661.4116],
#         [629.5819],
#         [605.7292],
#         [540.7626]])
# tensor([[ 55.1870,   3.7075],
#         [ 89.5518,   2.2674],
#         [ 79.5428,   3.1105],
#         [101.5624,   5.1931],
#         [ 75.4099,   5.6994],
#         [ 71.7651,   6.4778],
#         [ 65.0180,   5.0165],
#         [ 81.5224,   4.0973],
#         [ 71.8690,   3.5059],
#         [ 62.8545,   2.9795]])
#  tensor([[ 576.8783],
#         [ 953.4578],
#         [ 832.6780],
#         [1009.8335],
#         [ 744.4354],
#         [ 692.2231],
#         [ 643.9666],
#         [ 835.7895],
#         [ 748.1535],
#         [ 674.4722]])
# tensor([[ 90.7806,   3.9144],
#         [ 87.6980,   5.2942],
#         [ 87.3042,   5.9046],
#         [ 93.5554,   5.2923],
#         [ 29.0292,   6.5009],
#         [104.3664,   3.8652],
#         [ 48.2495,   2.7508],
#         [ 32.2104,   7.0807],
#         [ 92.5785,   4.9552],
#         [ 54.8025,   5.5368]])
#  tensor([[ 934.9264],
#         [ 871.3132],
#         [ 852.0394],
#         [ 933.2417],
#         [ 262.8556],
#         [1063.8226],
#         [ 532.0435],
#         [ 283.1136],
#         [ 925.7686],
#         [ 542.5640]])
# tensor([[ 37.0151,   5.6954],
#         [116.5164,   6.2448],
#         [ 65.7078,   6.2791],
#         [ 79.9936,   5.8850],
#         [ 29.1545,   5.7309],
#         [114.4713,   3.6626],
#         [ 52.4023,   5.2828],
#         [ 27.7751,   6.4259],
#         [ 88.7188,   4.7750],
#         [ 54.9015,   6.0588]])
#  tensor([[ 356.9172],
#         [1136.2047],
#         [ 631.6765],
#         [ 786.5982],
#         [ 279.5583],
#         [1168.0410],
#         [ 523.4910],
#         [ 260.6451],
#         [ 889.5891],
#         [ 525.4819]])
# tensor([[105.5581,   5.3832],
#         [ 87.6706,   6.2787],
#         [ 75.9824,   4.2845],
#         [100.4389,   5.1634],
#         [ 77.1672,   3.3040],
#         [112.2032,   5.9603],
#         [ 51.6962,   7.7662],
#         [ 79.6912,   5.0061],
#         [ 57.4098,   5.1819],
#         [ 60.8982,   0.0000]])
#  tensor([[1043.0986],
#         [ 854.5595],
#         [ 772.4783],
#         [ 996.4360],
#         [ 798.6837],
#         [1099.8917],
#         [ 458.9112],
#         [ 796.1602],
#         [ 570.8126],
#         [ 704.0565]])
# tensor([[90.1657,  3.4786],
#         [55.7056,  5.7585],
#         [65.1686,  4.1448],
#         [68.4470,  6.2670],
#         [68.8029,  6.5478],
#         [98.2474,  8.1695],
#         [88.2741,  5.2184],
#         [86.6155,  6.5906],
#         [74.2182,  6.6055],
#         [70.9824,  4.6856]])
#  tensor([[931.5114],
#         [544.6651],
#         [672.8339],
#         [662.9172],
#         [648.1792],
#         [925.7335],
#         [884.1736],
#         [833.0221],
#         [712.7559],
#         [714.0649]])
# tensor([[ 96.0707,   6.4070],
#         [ 66.9805,   6.0366],
#         [105.9015,   4.2766],
#         [ 67.1931,   5.7611],
#         [ 48.9452,   4.9276],
#         [ 71.9061,   7.8008],
#         [ 72.6471,   6.9585],
#         [ 99.1666,   8.4422],
#         [ 35.4776,   6.1303],
#         [ 63.9094,   7.6967]])
#  tensor([[ 936.5764],
#         [ 650.7985],
#         [1072.2926],
#         [ 663.6830],
#         [ 491.6021],
#         [ 658.5704],
#         [ 695.4493],
#         [ 928.6196],
#         [ 336.6023],
#         [ 590.7652]])
# tensor([[ 61.8164,   4.8369],
#         [100.5428,   6.8982],
#         [ 33.4612,   6.2808],
#         [ 71.4067,   3.6308],
#         [ 41.2520,   4.0765],
#         [ 61.4260,   5.2110],
#         [ 66.2234,   4.2124],
#         [ 76.7514,   1.1517],
#         [ 93.2484,   7.2939],
#         [100.0699,   3.8019]])
#  tensor([[ 631.9848],
#         [ 966.6273],
#         [ 305.6772],
#         [ 737.1253],
#         [ 434.0635],
#         [ 620.8487],
#         [ 686.0481],
#         [ 853.9661],
#         [ 880.5599],
#         [1019.2613]])
# tensor([[98.6476,  5.1063],
#         [68.4426,  4.3996],
#         [56.4549,  6.0781],
#         [66.8249,  1.0268],
#         [88.9959,  4.5566],
#         [56.5161,  4.8864],
#         [58.4764,  7.3140],
#         [59.9159,  3.3494],
#         [20.0000,  4.2860],
#         [56.3675,  5.9968]])
#  tensor([[984.5982],
#         [698.0086],
#         [545.2007],
#         [751.2098],
#         [904.5969],
#         [569.9241],
#         [533.9019],
#         [626.2933],
#         [212.1657],
#         [534.4274]])
# tensor([[ 67.2812,   3.5019],
#         [106.6694,   6.7446],
#         [ 93.5709,   0.8825],
#         [ 67.6649,   6.3355],
#         [ 34.6052,   8.2496],
#         [ 86.1156,   8.6585],
#         [ 73.4258,   4.5143],
#         [ 84.1379,   4.6325],
#         [ 83.6580,   5.2004],
#         [ 21.7701,   5.5713]])
#  tensor([[ 702.8344],
#         [1021.4650],
#         [1022.6141],
#         [ 639.3442],
#         [ 287.0832],
#         [ 787.0800],
#         [ 741.0945],
#         [ 856.6406],
#         [ 832.0321],
#         [ 207.8014]])
# tensor([[110.8886,   6.4121],
#         [ 39.5793,   7.4473],
#         [104.7852,   1.1982],
#         [ 78.8752,   4.2409],
#         [ 76.8655,   4.5073],
#         [ 49.5437,   4.1702],
#         [ 81.6064,   5.9849],
#         [ 62.7743,   5.5509],
#         [ 47.7817,   3.2162],
#         [ 81.1398,   5.2576]])
#  tensor([[1078.7343],
#         [ 349.8080],
#         [1120.3734],
#         [ 806.8069],
#         [ 777.1835],
#         [ 508.7928],
#         [ 799.4955],
#         [ 618.4514],
#         [ 513.6570],
#         [ 809.9269]])
# tensor([[85.0591,  4.9726],
#         [21.3099,  5.0950],
#         [77.7209,  6.8722],
#         [48.1748,  5.8538],
#         [62.9472,  4.7550],
#         [97.9300,  2.8759],
#         [40.8688,  4.5023],
#         [81.1605,  0.0000],
#         [87.5123,  6.8127],
#         [72.4680,  7.0137]])
#  tensor([[ 849.7713],
#         [ 208.4731],
#         [ 743.4366],
#         [ 462.6750],
#         [ 626.7590],
#         [1021.2908],
#         [ 424.7100],
#         [ 910.9041],
#         [ 838.1840],
#         [ 685.1801]])
# tensor([[67.1881,  5.1956],
#         [94.1689,  6.9088],
#         [51.5649,  5.3752],
#         [82.3382,  8.4563],
#         [53.2027,  8.1177],
#         [91.9740,  6.1572],
#         [72.3679,  4.2097],
#         [69.3305,  3.0005],
#         [38.2715,  4.2891],
#         [39.5398,  6.8751]])
#  tensor([[667.6276],
#         [910.7754],
#         [505.1908],
#         [751.2807],
#         [469.3829],
#         [903.1699],
#         [736.1575],
#         [742.0331],
#         [393.8688],
#         [357.9542]])
# tensor([[55.7823,  2.2083],
#         [62.8486,  2.8046],
#         [49.8117,  4.0874],
#         [34.1748,  3.9301],
#         [70.5695,  7.4904],
#         [41.5193,  8.6072],
#         [48.1321,  8.4050],
#         [56.2455,  4.0297],
#         [92.1932,  3.2726],
#         [41.6921,  5.6228]])
#  tensor([[612.1906],
#         [669.9375],
#         [516.9026],
#         [363.2907],
#         [660.5355],
#         [335.6003],
#         [414.6698],
#         [573.9153],
#         [964.1060],
#         [411.3912]])
# tensor([[66.6598,  8.5142],
#         [47.9234,  4.2154],
#         [54.4864,  5.6567],
#         [89.6289,  2.8724],
#         [65.3723,  5.4266],
#         [34.7805,  5.6395],
#         [69.7837,  2.4379],
#         [68.6604,  1.4020],
#         [83.0779,  4.9060],
#         [83.5667,  4.0346]])
#  tensor([[591.8206],
#         [487.5728],
#         [533.5338],
#         [933.9634],
#         [652.3672],
#         [333.8213],
#         [748.2943],
#         [753.0720],
#         [829.8041],
#         [859.7541]])
# tensor([[ 77.6390,   7.6457],
#         [ 93.8798,   5.0398],
#         [ 76.1464,   7.6219],
#         [ 29.3200,   4.1046],
#         [ 85.3848,   4.0488],
#         [ 82.4188,   8.9850],
#         [ 78.3582,   3.5908],
#         [ 65.8408,   5.0916],
#         [ 53.0746,   3.4227],
#         [117.2285,   5.2670]])
#  tensor([[ 721.2542],
#         [ 941.6662],
#         [ 713.4449],
#         [ 299.2123],
#         [ 880.0067],
#         [ 737.8924],
#         [ 806.7421],
#         [ 655.6514],
#         [ 561.8754],
#         [1162.7505]])
# tensor([[54.4870,  4.2176],
#         [91.1010,  4.2552],
#         [56.4469,  6.5020],
#         [58.7846,  3.9987],
#         [63.2001,  4.8575],
#         [85.5019,  8.7274],
#         [72.1680,  7.5904],
#         [81.9601,  6.5233],
#         [80.0737,  3.7351],
#         [77.6393,  4.6841]])
#  tensor([[560.3885],
#         [920.0335],
#         [541.1273],
#         [615.4816],
#         [634.4818],
#         [765.7789],
#         [662.6236],
#         [788.3159],
#         [829.6830],
#         [778.3876]])
# tensor([[ 53.2173,   6.2418],
#         [ 70.8826,   1.2081],
#         [ 67.7016,   9.0330],
#         [100.2412,   8.0339],
#         [ 59.5034,   6.5545],
#         [ 45.9687,   5.1128],
#         [ 77.2053,   7.2785],
#         [ 95.4115,   4.0505],
#         [ 54.9675,   6.8531],
#         [ 93.6773,   9.8207]])
#  tensor([[506.9721],
#         [783.3853],
#         [600.7680],
#         [936.6056],
#         [567.3177],
#         [459.7480],
#         [728.3665],
#         [982.0792],
#         [512.6358],
#         [838.2946]])
# tensor([[62.6203,  3.0463],
#         [28.7460,  7.8522],
#         [55.6736,  5.2491],
#         [78.4553,  6.6321],
#         [23.4081,  0.0000],
#         [74.7305,  5.9380],
#         [45.7750,  3.2179],
#         [72.4008,  6.2235],
#         [49.7099,  8.0390],
#         [79.5790,  1.7186]])
#  tensor([[667.6472],
#         [230.1285],
#         [549.3731],
#         [751.2678],
#         [334.2793],
#         [728.7913],
#         [498.9073],
#         [694.6924],
#         [426.5281],
#         [865.2796]])
# tensor([[62.5536,  5.9722],
#         [74.7476,  2.0925],
#         [47.7675,  2.0002],
#         [51.0600,  6.6658],
#         [83.2612,  8.8972],
#         [75.6299,  3.8510],
#         [41.2541,  9.1990],
#         [88.0117,  3.8534],
#         [77.4184,  7.8113],
#         [96.1032,  1.5589]])
#  tensor([[ 601.3270],
#         [ 800.3517],
#         [ 538.8180],
#         [ 472.7903],
#         [ 760.2454],
#         [ 776.2852],
#         [ 334.4649],
#         [ 905.0954],
#         [ 713.3999],
#         [1025.5614]])
# tensor([[ 43.8611,   4.4167],
#         [ 82.5511,   3.8855],
#         [ 83.0793,   7.9422],
#         [ 20.0000,   5.6016],
#         [ 52.0162,   1.9035],
#         [ 46.2635,   2.7910],
#         [ 79.0355,   6.1566],
#         [ 34.1861,   2.2241],
#         [ 57.5266,   0.7997],
#         [103.9383,   6.5094]])
#  tensor([[ 451.0601],
#         [ 849.7646],
#         [ 767.6238],
#         [ 189.9605],
#         [ 587.5291],
#         [ 495.4473],
#         [ 770.0442],
#         [ 400.2039],
#         [ 661.0773],
#         [1009.0239]])
# tensor([[ 42.3719,   7.3498],
#         [ 50.2535,   5.4741],
#         [ 60.5813,   6.0300],
#         [110.7436,   4.7482],
#         [101.1335,   4.6865],
#         [ 74.6152,   8.8931],
#         [ 83.5382,   7.4599],
#         [ 84.7079,   1.9617],
#         [ 42.3383,   3.0247],
#         [ 72.5421,   2.8984]])
#  tensor([[ 375.7805],
#         [ 488.6591],
#         [ 584.8892],
#         [1117.5985],
#         [1019.4487],
#         [ 667.9384],
#         [ 777.8934],
#         [ 901.5836],
#         [ 461.9662],
#         [ 778.6089]])
# tensor([[ 24.8345,   4.8752],
#         [109.4636,   3.7205],
#         [ 48.6844,   5.0732],
#         [ 43.5516,   6.4384],
#         [121.8002,   5.0569],
#         [ 20.0000,   6.1265],
#         [ 55.0545,   1.3728],
#         [ 48.2068,   4.8870],
#         [ 71.3092,   4.5380],
#         [ 53.7724,   2.9902]])
#  tensor([[ 257.8808],
#         [1121.5334],
#         [ 481.4506],
#         [ 408.3294],
#         [1215.4073],
#         [ 183.1722],
#         [ 622.7621],
#         [ 480.6088],
#         [ 729.3699],
#         [ 575.0990]])
# tensor([[ 43.2085,   5.7028],
#         [113.6532,   5.6104],
#         [ 78.6820,   6.5807],
#         [ 68.6236,   6.3250],
#         [ 89.2427,   5.6931],
#         [ 69.3371,   4.5446],
#         [ 81.0832,   1.3844],
#         [ 54.5761,   3.5355],
#         [ 83.1299,   3.7431],
#         [ 20.0000,   7.1237]])
#  tensor([[ 428.9118],
#         [1132.2980],
#         [ 746.3535],
#         [ 658.8340],
#         [ 877.1800],
#         [ 705.4977],
#         [ 893.0588],
#         [ 572.8151],
#         [ 854.4930],
#         [ 151.6626]])
# tensor([[57.1165,  3.0870],
#         [66.9530,  8.4972],
#         [75.9595,  5.5209],
#         [53.2323,  5.2375],
#         [36.0845,  6.6368],
#         [63.2228,  2.5432],
#         [52.3581,  8.9544],
#         [81.2127, 10.0000],
#         [70.5184,  7.1939],
#         [53.7586,  5.2986]])
#  tensor([[610.9042],
#         [591.7063],
#         [743.2915],
#         [526.4588],
#         [333.0410],
#         [688.1863],
#         [447.5066],
#         [710.6008],
#         [664.4788],
#         [540.8063]])
# tensor([[63.8726,  8.7029],
#         [70.2885,  7.5790],
#         [90.1698,  6.9882],
#         [56.0000,  1.0398],
#         [71.3269,  4.5608],
#         [68.1447,  4.6879],
#         [65.4354,  5.1553],
#         [75.9589,  5.5561],
#         [56.8188,  3.4696],
#         [26.4237,  6.7657]])
#  tensor([[564.4562],
#         [646.1593],
#         [860.4930],
#         [642.0381],
#         [723.9747],
#         [684.4877],
#         [649.3775],
#         [746.1222],
#         [598.9098],
#         [229.3975]])
# tensor([[44.6375,  7.3741],
#         [51.4906,  3.8650],
#         [67.8738,  4.3838],
#         [77.5479,  3.8714],
#         [74.6495,  3.3636],
#         [34.7694,  4.8799],
#         [76.8352,  2.9985],
#         [81.9651,  7.4816],
#         [99.9121,  3.8817],
#         [76.1019,  2.7923]])
#  tensor([[ 403.0081],
#         [ 533.5361],
#         [ 699.3982],
#         [ 790.4471],
#         [ 785.4921],
#         [ 346.4308],
#         [ 817.2243],
#         [ 771.8298],
#         [1028.3982],
#         [ 805.2688]])
# tensor([[5.8295e+01, 2.3472e+00],
#         [7.5972e+01, 5.5288e+00],
#         [6.1431e+01, 8.0309e+00],
#         [8.7735e+01, 4.3763e+00],
#         [3.6943e+01, 1.2259e-02],
#         [6.8794e+01, 8.0019e+00],
#         [9.3454e+01, 6.2475e+00],
#         [8.7187e+01, 9.2409e+00],
#         [5.9366e+01, 3.0864e+00],
#         [8.0196e+01, 4.2736e+00]])
#  tensor([[633.3596],
#         [752.0048],
#         [554.2828],
#         [894.1530],
#         [459.4038],
#         [634.8984],
#         [907.4604],
#         [790.3558],
#         [610.7936],
#         [818.3414]])
# tensor([[63.3943,  1.5389],
#         [61.3990,  7.9635],
#         [59.4830,  2.1372],
#         [90.3701,  5.6660],
#         [53.8244,  6.5402],
#         [40.5082,  5.8119],
#         [44.4819,  6.3776],
#         [74.7666,  5.7618],
#         [56.2852,  9.9999],
#         [74.1895,  3.1237]])
#  tensor([[701.1873],
#         [556.4096],
#         [650.0025],
#         [893.4907],
#         [507.5768],
#         [393.1100],
#         [420.6656],
#         [734.0001],
#         [467.7184],
#         [773.8917]])
# tensor([[115.4870,   3.7609],
#         [ 64.8822,   6.6390],
#         [ 48.6177,   5.3818],
#         [ 83.1910,   3.4446],
#         [ 88.4668,   5.5775],
#         [ 59.2042,   7.2734],
#         [ 41.8076,   2.1132],
#         [ 65.4494,   0.5784],
#         [ 60.3294,   5.6778],
#         [ 51.5135,   5.6214]])
#  tensor([[1187.2312],
#         [ 619.4523],
#         [ 490.6794],
#         [ 870.3248],
#         [ 874.0414],
#         [ 536.2762],
#         [ 468.3396],
#         [ 740.0677],
#         [ 585.5378],
#         [ 502.4283]])
# tensor([[ 78.7863,   3.8485],
#         [103.3795,   6.8659],
#         [ 36.5534,   8.0953],
#         [ 53.1544,   5.4706],
#         [ 66.9234,   5.1768],
#         [ 27.3740,   3.5326],
#         [ 76.5543,   3.4909],
#         [ 80.7234,   4.9287],
#         [ 79.3884,   5.7626],
#         [ 95.3550,   3.6362]])
#  tensor([[817.6656],
#         [993.2268],
#         [291.2378],
#         [521.2256],
#         [663.3929],
#         [306.1437],
#         [803.8295],
#         [812.9543],
#         [778.1689],
#         [984.4066]])
# tensor([[ 89.5149,   2.3997],
#         [ 60.2481,   3.5401],
#         [ 66.1856,   4.5385],
#         [ 85.0314,   3.0032],
#         [ 40.1813,   6.3228],
#         [ 52.8162,   5.8287],
#         [ 64.4564,   5.4644],
#         [ 40.1662,   7.3526],
#         [100.6126,   5.8877],
#         [ 79.7654,   5.8865]])
#  tensor([[949.1570],
#         [629.1952],
#         [675.4796],
#         [887.3849],
#         [375.1146],
#         [511.4249],
#         [642.7921],
#         [347.9272],
#         [989.6104],
#         [777.4474]])
# tensor([[55.8446,  7.1803],
#         [96.4410,  3.3075],
#         [78.2350,  5.4177],
#         [46.2983,  0.5678],
#         [60.3696,  5.5244],
#         [61.1979,  2.9258],
#         [76.7819,  1.6173],
#         [76.1711,  2.6027],
#         [41.2388,  3.0298],
#         [68.3263,  7.8321]])
#  tensor([[508.4693],
#         [997.9905],
#         [774.3278],
#         [550.2609],
#         [589.5401],
#         [665.0355],
#         [835.2863],
#         [811.6832],
#         [447.6350],
#         [621.9801]])
# tensor([[122.1848,   4.1792],
#         [ 39.8659,   7.3552],
#         [ 70.4633,   4.2556],
#         [ 95.1390,   3.3293],
#         [ 71.3025,   4.4032],
#         [ 63.1320,   4.3564],
#         [ 41.5207,   4.2620],
#         [ 48.9319,   4.2337],
#         [ 62.5837,   3.6213],
#         [ 82.4763,   2.2343]])
#  tensor([[1236.0498],
#         [ 356.4283],
#         [ 713.5623],
#         [ 987.4953],
#         [ 719.6808],
#         [ 640.7342],
#         [ 434.0599],
#         [ 504.6253],
#         [ 648.9115],
#         [ 876.9525]])
# tensor([[ 55.1354,   4.5182],
#         [ 68.8580,   6.1094],
#         [ 87.3228,   6.2778],
#         [ 76.0058,   3.3461],
#         [ 62.0167,   6.3690],
#         [ 59.3124,   5.3233],
#         [107.3369,   5.5352],
#         [ 87.3114,   6.3210],
#         [113.8966,   0.9477],
#         [ 67.2803,   7.1116]])
#  tensor([[ 551.5450],
#         [ 660.1464],
#         [ 846.4545],
#         [ 796.6281],
#         [ 591.4647],
#         [ 581.6392],
#         [1063.6962],
#         [ 841.5519],
#         [1209.7107],
#         [ 636.2201]])
# tensor([[61.8530,  2.7613],
#         [86.6091,  4.3035],
#         [40.2926,  7.0377],
#         [40.6782,  8.2610],
#         [88.4168,  6.2463],
#         [40.2073,  5.3110],
#         [43.3801,  0.7899],
#         [89.2199,  9.3583],
#         [74.8855,  6.8724],
#         [67.7705,  4.3019]])
#  tensor([[671.4820],
#         [876.4576],
#         [364.0648],
#         [340.5401],
#         [857.0887],
#         [399.0646],
#         [522.8762],
#         [797.5393],
#         [705.1690],
#         [693.3209]])
# tensor([[72.8225,  3.8355],
#         [61.8468,  5.6151],
#         [64.3005,  1.4294],
#         [32.8859,  4.2356],
#         [41.0063,  9.5348],
#         [62.5627,  2.3057],
#         [70.4260,  5.4329],
#         [56.4069,  4.8514],
#         [65.3192,  1.8891],
#         [49.9502, 10.0000]])
#  tensor([[744.4750],
#         [605.6689],
#         [720.6931],
#         [345.2796],
#         [323.2917],
#         [675.8694],
#         [702.4042],
#         [560.2083],
#         [716.0561],
#         [395.4496]])
# tensor([[ 61.1288,   6.0775],
#         [101.4148,   9.3752],
#         [ 42.8861,   4.7044],
#         [117.1834,   5.1130],
#         [ 56.1568,   5.5767],
#         [ 92.5176,   4.4571],
#         [ 41.2137,   2.3237],
#         [ 44.5280,   5.0084],
#         [ 90.3397,  10.0000],
#         [102.1874,   6.4472]])
#  tensor([[ 592.5085],
#         [ 924.8358],
#         [ 434.9539],
#         [1173.2639],
#         [ 546.8666],
#         [ 932.6415],
#         [ 468.2306],
#         [ 443.5988],
#         [ 801.6862],
#         [ 996.8311]])
# tensor([[84.5096,  8.6949],
#         [33.2869,  6.0296],
#         [94.3117,  2.8730],
#         [59.4129,  3.9270],
#         [74.6388,  3.9139],
#         [50.1096,  3.8340],
#         [68.5798,  2.7234],
#         [76.8961,  1.0387],
#         [96.6729,  6.9554],
#         [74.4047,  4.6942]])
#  tensor([[780.1016],
#         [312.4814],
#         [989.4944],
#         [624.0811],
#         [757.9177],
#         [535.9587],
#         [735.7131],
#         [842.0767],
#         [918.2852],
#         [753.4466]])
# tensor([[72.4140,  6.2563],
#         [65.5433,  4.2191],
#         [39.9123,  7.9217],
#         [60.6322,  4.9322],
#         [70.5709,  3.8370],
#         [48.7394,  4.6833],
#         [53.0730,  7.1801],
#         [69.9141,  1.8623],
#         [43.1312,  7.2877],
#         [46.4233,  1.4594]])
#  tensor([[699.5113],
#         [665.0062],
#         [346.2282],
#         [603.5095],
#         [730.5081],
#         [492.3814],
#         [489.0537],
#         [761.2576],
#         [384.0009],
#         [536.1444]])
# tensor([[ 64.6506,   3.3520],
#         [ 37.7473,   3.8474],
#         [110.0337,   6.8239],
#         [ 64.9098,   9.6745],
#         [ 66.8270,   3.1154],
#         [ 74.8030,   6.4116],
#         [ 81.0808,   4.2137],
#         [ 69.8506,   4.8936],
#         [ 74.6990,   7.5389],
#         [ 53.1157,   5.7102]])
#  tensor([[ 685.8963],
#         [ 405.2984],
#         [1070.6818],
#         [ 554.3593],
#         [ 707.6426],
#         [ 722.0913],
#         [ 825.5113],
#         [ 703.0968],
#         [ 693.4871],
#         [ 519.1519]])
# tensor([[ 30.6291,   1.7969],
#         [103.9928,   3.6607],
#         [ 97.7816,   5.8665],
#         [ 25.5001,   6.8285],
#         [ 52.2988,   5.2666],
#         [ 81.8151,   0.2434],
#         [ 83.4074,   3.8658],
#         [ 65.1344,   5.4599],
#         [ 80.5872,   1.7619],
#         [ 58.7800,   5.2506]])
#  tensor([[ 375.9430],
#         [1072.3271],
#         [ 962.3716],
#         [ 213.7268],
#         [ 519.7800],
#         [ 908.0781],
#         [ 857.7809],
#         [ 639.2215],
#         [ 871.3195],
#         [ 583.8836]])
# tensor([[ 99.1826,   7.5707],
#         [ 73.1343,   2.5778],
#         [ 36.5417,   5.0728],
#         [117.6528,   5.1115],
#         [ 44.1316,   0.0000],
#         [ 64.1003,   5.4649],
#         [ 89.8233,   1.5249],
#         [ 64.8927,   2.0119],
#         [ 65.4864,   3.7686],
#         [102.4332,   6.9836]])
#  tensor([[ 943.0131],
#         [ 780.0522],
#         [ 362.4674],
#         [1174.4111],
#         [ 539.6932],
#         [ 630.8799],
#         [ 968.1259],
#         [ 701.8851],
#         [ 683.8181],
#         [ 981.5811]])
# tensor([[30.1944,  6.3409],
#         [70.1959,  4.5662],
#         [74.7234,  4.5635],
#         [57.8176,  8.6990],
#         [40.6642,  2.8840],
#         [75.5894,  3.7049],
#         [40.9115,  5.2396],
#         [85.5632,  8.0423],
#         [80.6656,  7.5367],
#         [42.3673,  9.3180]])
#  tensor([[286.1154],
#         [716.5210],
#         [752.5513],
#         [507.0730],
#         [450.0393],
#         [770.5247],
#         [404.7936],
#         [793.2186],
#         [757.3650],
#         [328.3882]])
# tensor([[63.3101,  8.6953],
#         [61.9921,  5.9226],
#         [78.6405,  4.2663],
#         [45.8647,  6.9240],
#         [79.5984,  3.6589],
#         [79.0626,  5.2076],
#         [60.1403,  3.6933],
#         [73.5527,  3.9381],
#         [67.0281,  9.8282],
#         [62.5234,  6.2924]])
#  tensor([[567.8505],
#         [606.5320],
#         [802.0923],
#         [419.8179],
#         [824.8877],
#         [787.6528],
#         [620.6726],
#         [754.3489],
#         [584.8122],
#         [607.1393]])
# tensor([[ 50.9835,   4.8487],
#         [113.2642,   5.8735],
#         [ 91.9263,   6.2822],
#         [ 89.3828,   3.2120],
#         [ 99.3019,   2.4348],
#         [ 81.8902,   5.1770],
#         [ 54.9351,   5.2338],
#         [ 37.2149,   5.0922],
#         [ 66.8043,   3.9502],
#         [ 71.0414,   7.3977]])
#  tensor([[ 519.1775],
#         [1117.5895],
#         [ 888.1584],
#         [ 935.0236],
#         [1048.1198],
#         [ 816.4450],
#         [ 549.8766],
#         [ 377.4591],
#         [ 692.4171],
#         [ 657.0596]])
# tensor([[67.1097,  7.9885],
#         [74.8426,  5.4510],
#         [74.2224,  8.8803],
#         [66.5516,  8.5406],
#         [51.3284,  6.6479],
#         [71.7234,  4.8881],
#         [74.4880,  8.6022],
#         [77.6015,  2.4530],
#         [54.2993,  3.3071],
#         [58.4141,  4.9099]])
#  tensor([[609.6945],
#         [735.0556],
#         [668.0080],
#         [595.3661],
#         [484.9125],
#         [722.8224],
#         [667.3693],
#         [825.8450],
#         [581.8129],
#         [586.7012]])
# tensor([[69.5176,  3.0542],
#         [58.6316,  7.8683],
#         [75.1824,  6.0784],
#         [69.9353,  5.5001],
#         [97.1629,  7.7888],
#         [72.9541,  4.5123],
#         [74.3655,  5.0956],
#         [70.0467,  3.9711],
#         [71.5891,  4.0449],
#         [57.6543,  6.5333]])
#  tensor([[738.5770],
#         [529.9673],
#         [731.7126],
#         [689.7779],
#         [912.3608],
#         [732.4613],
#         [747.4089],
#         [723.3275],
#         [738.3394],
#         [540.5693]])
# tensor([[ 51.8513,   7.0530],
#         [ 57.1579,   3.2433],
#         [ 68.3810,   4.4139],
#         [106.2329,   5.3277],
#         [ 69.8404,   1.9088],
#         [ 54.3495,   4.7390],
#         [ 70.5875,   6.9008],
#         [ 23.7786,   6.7120],
#         [ 74.3350,   3.6433],
#         [ 64.9337,   3.6266]])
#  tensor([[ 475.0369],
#         [ 607.5072],
#         [ 705.4756],
#         [1055.9879],
#         [ 755.3151],
#         [ 549.7365],
#         [ 673.1959],
#         [ 205.9435],
#         [ 769.4327],
#         [ 676.6660]])
# tensor([[ 78.2286,   4.5757],
#         [ 87.1409,   6.0681],
#         [ 69.5567,   5.1403],
#         [ 82.6967,   5.1904],
#         [ 68.2809,   3.9220],
#         [ 55.9877,   6.1241],
#         [ 90.7185,   2.1228],
#         [ 77.6052,   1.3728],
#         [ 71.5738,   3.8350],
#         [100.3443,   2.1124]])
#  tensor([[ 792.0710],
#         [ 849.0474],
#         [ 696.2950],
#         [ 819.3047],
#         [ 701.1815],
#         [ 540.0256],
#         [ 969.9515],
#         [ 850.4738],
#         [ 736.5840],
#         [1057.2219]])
# tensor([[ 47.6808,   6.8359],
#         [ 64.8726,   3.5411],
#         [ 64.7285,  10.0000],
#         [ 30.8745,   3.0212],
#         [ 44.8970,   4.3359],
#         [ 38.2566,   9.1680],
#         [ 98.2404,   2.1209],
#         [ 75.7932,   5.0540],
#         [ 53.7726,   4.1721],
#         [103.4453,   3.8372]])
#  tensor([[ 443.1581],
#         [ 674.6492],
#         [ 547.9495],
#         [ 342.1242],
#         [ 467.0865],
#         [ 301.6333],
#         [1040.1750],
#         [ 762.1331],
#         [ 550.3019],
#         [1055.3615]])
# tensor([[ 75.1498,   4.7439],
#         [ 90.9547,   5.3395],
#         [ 58.0762,   4.3003],
#         [ 73.8200,   6.8132],
#         [101.5396,   9.0737],
#         [ 42.5023,   2.7800],
#         [ 68.2322,   6.6126],
#         [ 85.9966,   6.5968],
#         [ 61.7509,   4.9697],
#         [ 45.8682,   5.1272]])
#  tensor([[749.9629],
#         [903.1398],
#         [585.9130],
#         [700.9956],
#         [937.2313],
#         [467.0975],
#         [639.4339],
#         [826.8408],
#         [614.9952],
#         [453.4320]])
# tensor([[ 59.3330,   4.3778],
#         [ 78.2065,   3.0124],
#         [ 73.8072,   3.3458],
#         [ 62.4656,   4.8409],
#         [111.7324,   2.7821],
#         [ 50.9393,   6.5674],
#         [ 80.2577,   4.5913],
#         [ 46.1988,   7.9204],
#         [ 78.1606,   1.5990],
#         [ 61.4854,   7.2250]])
#  tensor([[ 608.6091],
#         [ 815.2280],
#         [ 765.7275],
#         [ 627.4863],
#         [1165.8273],
#         [ 477.1471],
#         [ 813.5554],
#         [ 401.4337],
#         [ 851.0585],
#         [ 571.0533]])
# tensor([[108.2430,   7.8600],
#         [ 38.8247,   6.4010],
#         [ 58.4993,   5.8356],
#         [ 42.1531,   1.3668],
#         [ 90.6547,   3.7455],
#         [ 59.4388,   5.9299],
#         [ 59.9821,   2.2392],
#         [ 63.2740,   3.8208],
#         [113.6289,   5.2753],
#         [ 71.2184,   6.2594]])
#  tensor([[1021.1246],
#         [ 362.1357],
#         [ 569.8725],
#         [ 497.0170],
#         [ 930.4954],
#         [ 575.9628],
#         [ 667.1757],
#         [ 662.7255],
#         [1134.9835],
#         [ 684.0466]])
# tensor([[77.7913,  2.6439],
#         [94.5732,  7.8511],
#         [73.7579,  2.7656],
#         [51.2871,  5.4074],
#         [93.3296,  7.4792],
#         [71.2362,  4.2464],
#         [54.8026,  5.9190],
#         [37.9136,  3.4422],
#         [50.6141,  3.8059],
#         [71.6946,  7.5916]])
#  tensor([[827.7068],
#         [889.5610],
#         [787.1587],
#         [510.9114],
#         [881.9207],
#         [731.0551],
#         [527.9691],
#         [414.8657],
#         [527.3223],
#         [660.5951]])
# tensor([[ 70.4572,   7.9255],
#         [ 92.5580,   1.2106],
#         [100.6033,   6.0229],
#         [ 80.3093,   1.3868],
#         [ 49.2790,   5.4496],
#         [102.0256,   4.8869],
#         [ 98.0723,   8.8232],
#         [ 84.7727,   6.8746],
#         [ 68.5667,   4.7421],
#         [ 98.3053,   4.5322]])
#  tensor([[ 646.6079],
#         [1002.8898],
#         [ 985.4119],
#         [ 875.1196],
#         [ 483.6440],
#         [1016.1164],
#         [ 904.9938],
#         [ 808.1884],
#         [ 691.6396],
#         [ 991.3419]])
# tensor([[ 96.8970,   5.4027],
#         [ 72.5854,   5.3712],
#         [ 71.9752,   1.4040],
#         [ 67.4160,   3.7705],
#         [ 55.7696,   1.4079],
#         [ 36.3493,   4.8550],
#         [100.4824,   5.6865],
#         [ 48.9828,   5.2405],
#         [ 98.2422,   4.1555],
#         [ 55.6764,   7.1533]])
#  tensor([[ 959.8988],
#         [ 714.4495],
#         [ 781.6603],
#         [ 698.0811],
#         [ 633.7989],
#         [ 361.3237],
#         [ 991.5753],
#         [ 484.2141],
#         [1003.9005],
#         [ 508.8595]])
# tensor([[47.7561,  4.1365],
#         [61.9956,  2.5894],
#         [80.5124,  6.5305],
#         [69.8551,  6.7640],
#         [67.3943,  6.0754],
#         [59.3459,  5.5884],
#         [88.5283,  5.4368],
#         [57.6888,  6.4884],
#         [73.7008,  4.6046],
#         [64.0811,  5.8799]])
#  tensor([[498.8620],
#         [676.8210],
#         [776.1808],
#         [671.0814],
#         [649.8747],
#         [576.6901],
#         [870.9653],
#         [550.9893],
#         [746.5459],
#         [623.2168]])
# tensor([[ 56.4161,   5.7664],
#         [ 81.0945,   4.2848],
#         [ 79.0465,   8.6808],
#         [ 48.9698,   4.9438],
#         [ 94.5011,   9.9311],
#         [ 95.3393,   5.3339],
#         [ 81.0809,   5.1112],
#         [109.1407,   7.0463],
#         [ 20.5564,   3.2307],
#         [ 79.2437,   3.6986]])
#  tensor([[ 547.5710],
#         [ 828.6618],
#         [ 713.3344],
#         [ 490.3254],
#         [ 846.1863],
#         [ 947.0630],
#         [ 811.7655],
#         [1060.0775],
#         [ 237.7162],
#         [ 815.2144]])
# tensor([[ 70.3225,   6.6965],
#         [ 72.8561,   4.8055],
#         [ 65.5180,   2.4358],
#         [ 83.9851,   6.1446],
#         [ 87.1909,   6.7070],
#         [ 47.1225,   5.7684],
#         [120.4495,   2.6958],
#         [ 34.8417,   5.7833],
#         [ 73.8390,   6.5475],
#         [ 82.4682,   5.8958]])
#  tensor([[ 657.3559],
#         [ 728.7401],
#         [ 709.4862],
#         [ 811.6891],
#         [ 842.6169],
#         [ 454.2532],
#         [1251.5249],
#         [ 331.2614],
#         [ 715.3404],
#         [ 807.6386]])
# tensor([[84.2217,  6.3772],
#         [82.5963,  9.2629],
#         [53.9631,  4.9857],
#         [50.9167,  4.6294],
#         [76.2428,  5.5679],
#         [81.7673,  6.9615],
#         [60.7015,  5.0510],
#         [75.5763,  3.9625],
#         [57.3621,  6.6539],
#         [67.0522,  3.5872]])
#  tensor([[816.2305],
#         [738.7677],
#         [531.6157],
#         [521.6643],
#         [750.0964],
#         [771.3768],
#         [610.6881],
#         [787.4890],
#         [542.5211],
#         [701.8140]])
# tensor([[88.8250,  8.4082],
#         [91.3660,  8.5420],
#         [72.3951,  3.9765],
#         [55.7767,  3.8757],
#         [94.7365,  0.8575],
#         [63.2657,  4.6675],
#         [91.6088,  6.9666],
#         [61.8905,  0.6495],
#         [68.1858,  5.6961],
#         [90.7572,  1.5907]])
#  tensor([[ 823.4193],
#         [ 845.1013],
#         [ 752.1447],
#         [ 588.1978],
#         [1030.0016],
#         [ 640.0536],
#         [ 869.0296],
#         [ 706.6568],
#         [ 665.1355],
#         [ 974.0235]])
# tensor([[ 94.4909,   2.6710],
#         [ 73.5177,   8.5753],
#         [ 47.2817,   7.5150],
#         [ 63.7522,   2.0814],
#         [113.4318,   2.7391],
#         [ 71.5213,   6.5153],
#         [102.9122,   1.2087],
#         [ 80.3121,   6.2720],
#         [ 69.9384,   2.7190],
#         [117.1087,   2.9475]])
#  tensor([[ 987.3268],
#         [ 660.0427],
#         [ 415.8908],
#         [ 698.6502],
#         [1181.4581],
#         [ 686.5091],
#         [1106.8893],
#         [ 775.3632],
#         [ 738.8143],
#         [1201.9980]])
# tensor([[78.4870,  6.9861],
#         [69.5876,  6.8755],
#         [61.7059,  5.7536],
#         [78.9182,  7.0207],
#         [56.9277,  5.0532],
#         [76.7455,  8.2241],
#         [57.8853,  5.9591],
#         [84.3400,  4.7772],
#         [97.1521,  3.3058],
#         [63.2223,  8.0706]])
#  tensor([[ 740.6452],
#         [ 655.9570],
#         [ 601.8614],
#         [ 746.9571],
#         [ 577.6641],
#         [ 703.8596],
#         [ 552.1364],
#         [ 841.6254],
#         [1012.9535],
#         [ 574.6092]])
# tensor([[ 56.6040,   4.3160],
#         [ 68.3189,   2.9018],
#         [105.6002,   1.7927],
#         [ 66.1311,   6.7040],
#         [ 69.9018,   0.7788],
#         [ 37.1048,   0.0000],
#         [ 64.9801,   7.7802],
#         [ 92.9828,   4.9026],
#         [ 48.1079,   4.3234],
#         [ 47.1996,   2.3343]])
#  tensor([[ 580.7699],
#         [ 729.2665],
#         [1120.8732],
#         [ 622.7297],
#         [ 773.5244],
#         [ 471.8383],
#         [ 591.4362],
#         [ 943.6835],
#         [ 498.2370],
#         [ 527.5172]])
# tensor([[ 29.4749,   5.7375],
#         [ 82.9369,   5.6744],
#         [ 68.4594,   5.7269],
#         [ 23.0970,   6.3418],
#         [ 67.4022,   3.2830],
#         [ 65.5825,   5.5082],
#         [ 61.5361,   3.8893],
#         [ 69.6241,   6.3102],
#         [104.4074,   4.4897],
#         [ 42.5742,   6.9382]])
#  tensor([[ 279.4456],
#         [ 809.2556],
#         [ 664.7046],
#         [ 203.1064],
#         [ 707.1204],
#         [ 648.3398],
#         [ 635.0178],
#         [ 665.8704],
#         [1058.8167],
#         [ 387.6085]])
# tensor([[90.7741,  5.7132],
#         [77.8873,  8.7957],
#         [96.2760,  8.1809],
#         [75.7558,  4.9567],
#         [93.0150,  3.2410],
#         [70.1027,  8.2119],
#         [43.8016,  4.4394],
#         [23.9644,  4.6690],
#         [90.1093,  7.4070],
#         [72.0917,  7.7399]])
#  tensor([[893.2560],
#         [701.6667],
#         [896.5034],
#         [760.6112],
#         [965.0804],
#         [640.5834],
#         [453.5937],
#         [251.7331],
#         [849.0333],
#         [656.8272]])
# tensor([[ 71.7588,   4.0403],
#         [ 61.8449,   4.5664],
#         [ 84.6880,   3.2194],
#         [ 74.4891,   8.3698],
#         [ 61.8296,   7.0044],
#         [104.6752,   8.2945],
#         [ 55.1142,   6.8663],
#         [ 58.3168,   5.5088],
#         [ 70.4496,   8.3166],
#         [ 99.8110,   7.5305]])
#  tensor([[736.9845],
#         [628.7120],
#         [876.9066],
#         [679.3129],
#         [576.6843],
#         [979.6012],
#         [510.7999],
#         [569.7928],
#         [643.1772],
#         [944.0453]])
# tensor([[34.3632,  3.8923],
#         [60.8044,  6.8173],
#         [73.3276,  8.4384],
#         [50.2309,  6.8836],
#         [61.8768,  4.6025],
#         [41.9806,  6.0477],
#         [72.1668,  6.2818],
#         [69.3929,  1.5140],
#         [49.0702,  4.8446],
#         [54.8096,  3.2603]])
#  tensor([[352.8885],
#         [568.1517],
#         [665.4920],
#         [468.8158],
#         [629.2388],
#         [404.2134],
#         [697.9274],
#         [763.6566],
#         [496.2915],
#         [585.8749]])
# tensor([[ 52.9951,   4.0887],
#         [103.3811,   1.0740],
#         [ 67.9704,   6.5911],
#         [ 70.8415,   5.5920],
#         [ 60.6068,   6.5661],
#         [ 56.2478,   4.6281],
#         [ 43.0468,   3.5131],
#         [106.1270,   2.6319],
#         [ 58.4978,   4.1705],
#         [ 53.1914,   9.2260]])
#  tensor([[ 545.8444],
#         [1109.1420],
#         [ 656.5137],
#         [ 701.7288],
#         [ 580.8699],
#         [ 572.8639],
#         [ 464.4534],
#         [1108.2108],
#         [ 597.9460],
#         [ 446.9626]])
# tensor([[39.2658,  5.5425],
#         [45.5899,  6.8157],
#         [22.6311,  7.9478],
#         [46.3580,  1.8364],
#         [72.7199,  4.4147],
#         [73.3892,  7.9089],
#         [74.5966,  7.1772],
#         [20.0000,  3.9079],
#         [70.9551,  3.3613],
#         [71.4152,  4.7561]])
#  tensor([[373.3173],
#         [414.1554],
#         [170.5887],
#         [532.9444],
#         [738.6328],
#         [683.9737],
#         [706.8284],
#         [212.9767],
#         [744.0378],
#         [723.7294]])
# tensor([[88.4547,  4.3187],
#         [67.3501,  0.7303],
#         [94.9691,  5.7243],
#         [76.3118,  3.7284],
#         [41.7657,  4.6109],
#         [62.2433,  3.5608],
#         [66.5004,  7.3950],
#         [73.8902,  4.4527],
#         [74.4156,  6.0662],
#         [72.7555,  7.0971]])
#  tensor([[893.6849],
#         [761.5554],
#         [935.6035],
#         [795.1035],
#         [419.4673],
#         [644.6777],
#         [621.7151],
#         [748.8033],
#         [718.5955],
#         [687.2177]])
# tensor([[73.1499,  4.2279],
#         [79.2050,  5.3905],
#         [61.9457,  3.8001],
#         [76.3437,  7.0953],
#         [75.0965,  4.8790],
#         [82.5038,  2.6677],
#         [54.0889,  5.5032],
#         [35.3597,  7.3395],
#         [53.1891,  7.7884],
#         [49.8664,  0.3483]])
#  tensor([[741.4814],
#         [786.1688],
#         [649.8210],
#         [719.0392],
#         [749.3445],
#         [870.0691],
#         [529.5381],
#         [303.5749],
#         [479.5479],
#         [588.2290]])
# tensor([[53.3089,  5.3008],
#         [78.8405,  8.0191],
#         [59.4860,  9.4739],
#         [29.9524,  6.2951],
#         [79.4293,  6.1247],
#         [76.5911,  6.0064],
#         [65.8926,  4.8028],
#         [89.0142,  4.1630],
#         [71.8318,  4.1354],
#         [49.0047,  6.6863]])
#  tensor([[522.1682],
#         [721.5480],
#         [497.6681],
#         [280.7940],
#         [763.5552],
#         [743.5893],
#         [664.4688],
#         [908.8818],
#         [731.9817],
#         [455.1258]])

# %% [markdown]
# ### Model definition
#
# We work with linear regression so we need to define a linear regression model as $\hat{y} = \mathbf{x}^T \mathbf{w} + b$.
# Here $\mathbf{w}$ and $b$ are the unknown parameters that we need to learn.

# %%
# define a function lin_reg(inputs, weight, bias) -> y_hat 
# --- YOUR CODE HERE ---
w = torch.normal(0, 0.01, size=(2, 1), requires_grad=True)
b = torch.zeros(1, requires_grad=True)

def lin_reg(features, weights, bias):
    return torch.matmul(features, weights) + bias

# %%
# use true parameters and check errors
# --- YOUR CODE HERE ---
lin_reg(features, true_w, true_b)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22264/1664028624.py in <module>
#       1 # use true parameters and check errors
#       2 # --- YOUR CODE HERE ---
# ----> 3 lin_reg(features, true_w, true_b)
#
# ~\AppData\Local\Temp/ipykernel_22264/948847674.py in lin_reg(features, weights, bias)
#       5
#       6 def lin_reg(features, weights, bias):
# ----> 7     return torch.matmul(features, weights) + bias
#
# RuntimeError: expected scalar type Float but found Long

# %%
# use random parameters and check errors
# --- YOUR CODE HERE ---

true_w = torch.tensor([5, -10])
#rand_true_w = torch.tensor(np.random.uniform(low=1.0, high=10.0, size=(2,)))

true_b = 70.0
#rand_true_b = float(np.random.uniform(low=50.0, high=100.0, size=(1,)))

lin_reg(features, true_w, true_b)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22264/3631257317.py in <module>
#       8 #rand_true_b = float(np.random.uniform(low=50.0, high=100.0, size=(1,)))
#       9
# ---> 10 lin_reg(features, true_w, true_b)
#
# ~\AppData\Local\Temp/ipykernel_22264/948847674.py in lin_reg(features, weights, bias)
#       5
#       6 def lin_reg(features, weights, bias):
# ----> 7     return torch.matmul(features, weights) + bias
#
# RuntimeError: expected scalar type Float but found Long

# %% [markdown]
# ### Loss function definition
#
# We use squared error loss function $$\mathcal{L} = \frac{1}{n} \sum_{i = 1}^{n} \frac{1}{2}(\hat{y}^{(i)} - y^{(i)})^2$$

# %%
# define a function loss_func(labels, preds) -> error
# --- YOUR CODE HERE ---

# %% [markdown]
# ### Optimization algorithm
#
# We will use minibatch stochastic gradient descent to update the parameters. The function should update the parameter values by a small step opposite to the gradient direction (which indicates the steepest increase). $\mathbf{w} \leftarrow \mathbf{w} - \alpha \nabla_w$

# %%
# define a function sgd_step(params, learn_rate, batch_size) that does one step in the gradient updates
# --- YOUR CODE HERE ---

# %% [markdown]
# ### Model training
#
# After all the pieces are ready, we implemen the main training loop. It needs to do the following:
#
# * initiate randomly the linear model parameters $(\mathbf{w}, b)$
# * repeat for each epoch (unitl done)
#     * load batch of data
#     * do linear model precitions with current parameter values
#     * calculate loss
#     * get gradients
#     * update parameter values

# %%
# write the training procedure
# --- YOUR CODE HERE ---

# %% [markdown]
# ### Normalize imput data
#
# It is usually better to normalize your input data to remove any scaling differences. The normalized data shall have zero mean $\mu$ and standard deviation $\sigma$ 1.
# $$x_{norm} = \frac{x - \mu(x)}{\sigma(x)}$$

# %%
### Normalize input data so that each input dimension has mean = 0 and std = 1
# --- YOUR CODE HERE ---

# %% [markdown]
# ### Plot data again
#
# Just to check the result of the normalization step, plot again the scatter of price agains the normalized size.

# %%
# --- YOUR CODE HERE ---

# %% [markdown]
# ### Train over normalized data

# %%
# --- YOUR CODE HERE ---
